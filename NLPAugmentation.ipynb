# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedterry/NLP_for_ML/blob/master/NLPAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Augmentation

# %%
conversation_dataset = [
  ["hi","how are you","fine thanks","great. Take care"],
  ["heya","ugh go away","why are you so mean to me","im just in a bad mood"],
  ["what is your name","im Carla","nice to meet you Carla","likewise"]
]

# %% [markdown]
# ## Shifting Conversations

# %% [markdown]
# Varying the Position of Sentences within a conversation by shifting the text to the left / right is a useful trick for sequence data

# %%
def shift_examples(examples):
  return [
    example[idx:] for example in examples for idx in range(
      len(example)
    ) if len(example[idx:]) > 1
  ]
shift_examples(conversation_dataset)
# Out:
# [['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['why are you so mean to me', 'im just in a bad mood'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise']]

# %% [markdown]
# ## Combining Conversations

# %%
def combine_examples(examples):
  return [
    first_example + second_example for idx,first_example in enumerate(
        examples
    ) for jdx, second_example in enumerate(
        examples
    ) if idx != jdx
  ]

combine_examples(conversation_dataset)
# Out:
# [['hi',
#   'how are you',
#   'fine thanks',
#   'great. Take care',
#   'heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['hi',
#   'how are you',
#   'fine thanks',
#   'great. Take care',
#   'what is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood',
#   'hi',
#   'how are you',
#   'fine thanks',
#   'great. Take care'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood',
#   'what is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise'],
#  ['what is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise',
#   'hi',
#   'how are you',
#   'fine thanks',
#   'great. Take care'],
#  ['what is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise',
#   'heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood']]

# %% [markdown]
# ## Substituting Synonyms (using Wordnet)

# %%
import nltk 
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.corpus import wordnet as wn
from string import punctuation

# %%
def synonyms(word, pos_tag):
  return list(
    {
      lemma.replace("_"," ").replace("-"," ") for synset in wn.synsets(
          _clean_word(word),
          pos_tag,
      ) for lemma in synset.lemma_names()
    }
  )

def _clean_word(word):
  return word.lower().strip(punctuation)

# %%
synonyms("Test.", 'n')
# Out:
# ['mental test',
#  'trial',
#  'mental testing',
#  'run',
#  'trial run',
#  'test',
#  'psychometric test',
#  'examination',
#  'exam',
#  'tryout']

# %%
synonyms("Test.", 'v')
# Out:
# ['test', 'prove', 'quiz', 'try out', 'try', 'examine', 'screen', 'essay']

# %%
def _tokenise(sentence):
  return nltk.word_tokenize(sentence)

def _infer_pos_tags(tokens):
  return [
    (
      token,
      _convert_nltk_to_wordnet_tag(nltk_tag)
    ) for token,nltk_tag in nltk.pos_tag(tokens)
  ]

def _convert_nltk_to_wordnet_tag(pos_tag):
  NOUN = "NN"
  VERB = "VB"
  ADJECTIVE = "JJ"
  ADVERB = "RB"
  if pos_tag.startswith(NOUN):
    return "n"
  if pos_tag.startswith(VERB):
    return "v" 
  if pos_tag.startswith(ADVERB):
    return "r"
  if pos_tag.startswith(ADJECTIVE):
    return "a"

# %%
_infer_pos_tags(
    tokens = _tokenise("testing, testing, this is a test")
)
# Out:
# [('testing', 'v'),
#  (',', None),
#  ('testing', 'v'),
#  (',', None),
#  ('this', None),
#  ('is', 'v'),
#  ('a', None),
#  ('test', 'n')]

# %%
def synonymous_examples(examples, include_verbs = False):
  synonymous = []
  for example in examples:
    for idx,sentence in enumerate(example):
      tokens = _tokenise(sentence)
      tagged_words = _infer_pos_tags(tokens)
      for jdx,word_pos in enumerate(tagged_words):
        word, pos_tag = word_pos
        if pos_tag and (include_verbs or pos_tag != "v"):
          for synonym in synonyms(word, pos_tag):
              new_tokens = tokens[:jdx] + [synonym] + tokens[jdx+1:]
              new_sentence = ' '.join(new_tokens)
              new_example = example[:idx] + [new_sentence] + example[idx+1:]
              synonymous.append(new_example)
  return synonymous

# %%
synonymous_examples(
  [
    ["This is a little test", "yes it is"],
    ["this is another test", "no it isn't"]
  ]
)
# Out:
# [['This is a slight test', 'yes it is'],
#  ['This is a little test', 'yes it is'],
#  ['This is a fiddling test', 'yes it is'],
#  ['This is a picayune test', 'yes it is'],
#  ['This is a small test', 'yes it is'],
#  ['This is a footling test', 'yes it is'],
#  ['This is a lilliputian test', 'yes it is'],
#  ['This is a short test', 'yes it is'],
#  ['This is a trivial test', 'yes it is'],
#  ['This is a petty test', 'yes it is'],
#  ['This is a niggling test', 'yes it is'],
#  ['This is a piddling test', 'yes it is'],
#  ['This is a minuscule test', 'yes it is'],
#  ['This is a piffling test', 'yes it is'],
#  ['This is a little mental test', 'yes it is'],
#  ['This is a little trial', 'yes it is'],
#  ['This is a little mental testing', 'yes it is'],
#  ['This is a little run', 'yes it is'],
#  ['This is a little trial run', 'yes it is'],
#  ['This is a little test', 'yes it is'],
#  ['This is a little psychometric test', 'yes it is'],
#  ['This is a little examination', 'yes it is'],
#  ['This is a little exam', 'yes it is'],
#  ['This is a little tryout', 'yes it is'],
#  ['This is a little test', 'yes it is'],
#  ['this is another mental test', "no it isn't"],
#  ['this is another trial', "no it isn't"],
#  ['this is another mental testing', "no it isn't"],
#  ['this is another run', "no it isn't"],
#  ['this is another trial run', "no it isn't"],
#  ['this is another test', "no it isn't"],
#  ['this is another psychometric test', "no it isn't"],
#  ['this is another examination', "no it isn't"],
#  ['this is another exam', "no it isn't"],
#  ['this is another tryout', "no it isn't"]]

# %%
len(synonymous_examples(conversation_dataset))
# Out:
# 128

# %%
len(synonymous_examples(conversation_dataset, include_verbs=True))
# Out:
# 254

# %% [markdown]
# ## Back Translating (aka Spinning)

# %%
from textblob import TextBlob

# %%
def _spin_text(text, foreign_language): 
  try: 
    spun_text = _clean_word(
      TextBlob(
        TextBlob(text).translate(
          from_lang="en",
          to=foreign_language
        ).raw
      ).translate(
        from_lang=foreign_language,
        to="en"
      ).raw
    )
    return spun_text if spun_text != _clean_word(text) else None
  except:
    return None

# %%
_spin_text("i have given you a small test", "es")
# Out:
# "i've done a little test"

# %%
_spin_text("that's an entirely different kettle of fish", "ar")
# Out:
# 'this kettle is completely different than fish'

# %%
def rephrase_examples(examples):
  rephrased_examples = []
  repeat_rephrasings = []
  for example in examples:
    for idx,sentence in enumerate(example):
      sentence_spun_from_spanish = _spin_text(sentence, "es")
      if sentence_spun_from_spanish and sentence_spun_from_spanish not in repeat_rephrasings:
        repeat_rephrasings.append(sentence_spun_from_spanish)
        rephrased_examples.append(
          example[:idx] + [sentence_spun_from_spanish] + example[idx+1:]
        )
      sentence_spun_from_arabic = _spin_text(sentence, "ar")
      if sentence_spun_from_arabic and sentence_spun_from_arabic not in repeat_rephrasings:
        repeat_rephrasings.append(sentence_spun_from_arabic)
        rephrased_examples.append(
          example[:idx] + [sentence_spun_from_arabic] + example[idx+1:]
        )
  return examples + rephrased_examples

rephrase_examples(conversation_dataset)
# Out:
# [['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['hi', 'how are you', 'well thanks', 'great. Take care'],
#  ['hi', 'how are you', 'good thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'excellent. beware'],
#  ['hi', 'how are you', 'fine thanks', 'great. take care of yourself'],
#  ['hey', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you cruel with me', 'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', "i'm in a bad mood"],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   "i'm just in a bad mood"],
#  ["what's your name", 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', "i'm carla", 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'i am carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'equally'],
#  ['what is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'in a similar way']]

# %% [markdown]
# ## Inserting words (using BERT)

# %%
# !pip3 install -U pytorch-pretrained-bert
# Out:
# Collecting pytorch-pretrained-bert
#   Downloading https://files.pythonhosted.org/packages/d7/e0/c08d5553b89973d9a240605b9c12404bcf8227590de62bae27acbcfe076b/pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123kB)
#      |████████████████████████████████| 133kB 2.8MB/s
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.10.32)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.17.4)
# Requirement already satisfied, skipping upgrade: regex in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (2019.12.9)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (2.21.0)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (4.28.1)
# Requirement already satisfied, skipping upgrade: torch>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.3.1)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (0.9.4)
# Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (0.2.1)
# Requirement already satisfied, skipping upgrade: botocore<1.14.0,>=1.13.32 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (1.13.32)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (2019.11.28)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.32->boto3->pytorch-pretrained-bert) (0.15.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.32->boto3->pytorch-pretrained-bert) (2.6.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<2.8.1,>=2.1; python_version >= "2.7"->botocore<1.14.0,>=1.13.32->boto3->pytorch-pretrained-bert) (1.12.0)
# Installing collected packages: pytorch-pretrained-bert
# Successfully installed pytorch-pretrained-bert-0.6.2

# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

# %%
model_name = 'bert-base-uncased'
bert_tokeniser = BertTokenizer.from_pretrained(model_name)
bert_model = BertForMaskedLM.from_pretrained(model_name)
# Out:
# 100%|██████████| 407873900/407873900 [00:30<00:00, 13529294.61B/s]

# %%
def _format_model_input(text, tokeniser, insert_mask_at_idx):
  tokens = tokeniser.tokenize(
    f"[CLS] {text} [SEP]"
  )
  tokens_with_mask = tokens[:insert_mask_at_idx] + [
    "[MASK]"
  ] + tokens[insert_mask_at_idx:]
  return torch.tensor(
    [
      tokeniser.convert_tokens_to_ids(tokens_with_mask)
    ]
  )

def _format_model_output(model_output, token_idxs, tokeniser, masked_idx):
  tokens = tokeniser.convert_ids_to_tokens(
    token_idxs.tolist()[0]
  )
  tokens[masked_idx] = tokeniser.convert_ids_to_tokens(
    [
      torch.argmax(
        model_output[0, masked_idx]
      ).item()
    ]
  )[0]
  return ' '.join(tokens[1:-1]).replace("##","")

# %%
def _insert_mask_and_predict(sentence, model, tokeniser, masked_idx):
  tokens_with_mask_inserted = _format_model_input(
    text = sentence,
    tokeniser = tokeniser,
    insert_mask_at_idx = masked_idx,
  )
  segment_ids = torch.tensor(
    [[0]*len(tokens_with_mask_inserted)]
  )
  with torch.no_grad():
    return _format_model_output(
      model_output = model(
        tokens_with_mask_inserted,
        segment_ids
      ),
      tokeniser = tokeniser,
      token_idxs = tokens_with_mask_inserted,
      masked_idx = masked_idx,
    )

# %%
def _insert_words(example):
  new_examples = [example]
  idx = 1
  try:
    while True:
      new_examples.append(
        _insert_mask_and_predict(
          sentence = example,
          model = bert_model,
          tokeniser = bert_tokeniser,
          masked_idx = idx
        )
      )
      idx += 1
  except:
    new_examples.pop()
    return new_examples

# %%
_insert_words("i have two drinks")
# Out:
# ['i have two drinks',
#  '" i have two drinks',
#  'i only have two drinks',
#  'i have my two drinks',
#  'i have two more drinks',
#  'i have two drinks .']

# %%
def bert_inserted_examples(examples):
  new_examples = []
  for example in examples:
    for idx,sentence in enumerate(example):
      for inserted_sentence in _insert_words(sentence):
        new_examples.append(
          example[:idx] + [inserted_sentence] + example[idx+1:]
        )
  return examples + new_examples

# %%
bert_inserted_examples(conversation_dataset)
# Out:
# [['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['" hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['hi .', 'how are you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['hi', '" how are you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how old are you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you ?', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you', '" fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine , thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks .', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', '" great . take care'],
#  ['hi', 'how are you', 'fine thanks', 'great job . take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . just take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . take good care'],
#  ['hi', 'how are you', 'fine thanks', 'great . take care .'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['- hey a',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['hey hey a',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['hey a !',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'oh u gh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'u gg gh go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'u gh , go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'u gh go go away',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'u gh go away .',
#   'why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   '" why are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why , are you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are ... you so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you being so mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so damn mean to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean things to me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to leave me',
#   'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me ?',
#   'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'i im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im not just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just not in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in such a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a really bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad - mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad mood .'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['" what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what exactly is your name',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise'],
#  ['what is in your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your real name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name ?', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', '- im carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name',
#   'im itating carla',
#   'nice to meet you Carla',
#   'likewise'],
#  ['what is your name', 'im carla .', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', '" nice to meet you carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice way to meet you carla', 'likewise'],
#  ['what is your name',
#   'im Carla',
#   'nice to finally meet you carla',
#   'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet the you carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you . carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you carla .', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'and likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise .']]

# %% [markdown]
# ## Generating longer conversations (using GPT-2)

# %%
# !pip3 install gpt-2-simple
# Out:
# Requirement already satisfied: gpt-2-simple in /usr/local/lib/python3.6/dist-packages (0.7)
# Requirement already satisfied: toposort in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.17.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.28.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2019.12.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.8)

# %%
from nltk.tokenize import sent_tokenize
import gpt_2_simple as gpt2
model_name = "774M"
gpt2.download_gpt2(model_name=model_name)
gpt2.load_gpt2(
  gpt2.start_tf_sess(), 
  model_name=model_name
)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 162Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 92.0Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 280Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 3.10Git [01:03, 48.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 373Mit/s]
# Fetching model.ckpt.meta: 2.10Mit [00:00, 120Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 113Mit/s]

# %%
def extend_conversations(examples):
  return examples + [
    _extend_conversation(
      '. '.join(example)
    ) for example in examples
  ]

def _extend_conversation(conversation_as_string):
  generated_samples = gpt2.generate(
    sess,
    model_name=model_name,
    prefix=conversation_as_string,
    length=100,
    return_as_list = True
  )
  n = len(
    sent_tokenize(
      conversation_as_string
    )
  )
  return sent_tokenize(
    generated_samples[0]
  )[:n+1]

# %%
extend_conversations(conversation_dataset)
# Out:
# [['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['hi.', 'how are you.', 'fine thanks.', 'great.', 'Take care.', 'I got it.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood because I lost in the qualifiers.',
#   'why are you so mean to me.'],
#  ['what is your name.',
#   'im Carla.',
#   'nice to meet you Carla.',
#   'likewise, my name is Carla.',
#   "Bill: How'd you get here?"]]

# %% [markdown]
# # Pipeline

# %%
def augment_dataset(dataset):
  dataset = extend_conversations(dataset)
  dataset = bert_inserted_examples(dataset)
  dataset = rephrase_examples(dataset)
  dataset = synonymous_examples(dataset)
  dataset = shift_examples(dataset)
  return dataset

# %%
augmented_dataset = augment_dataset(conversation_dataset)

# %%
augmented_dataset
# Out:
# [['how do you do', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hello', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['Hawaii', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hullo', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['howdy', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['Aloha State', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ["Hawai'i", 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['HI', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'o.k. thanks', 'great. Take care'],
#  ['how are you', 'o.k. thanks', 'great. Take care'],
#  ['o.k. thanks', 'great. Take care'],
#  ['hi', 'how are you', 'hunky dory thanks', 'great. Take care'],
#  ['how are you', 'hunky dory thanks', 'great. Take care'],
#  ['hunky dory thanks', 'great. Take care'],
#  ['hi', 'how are you', 'ok thanks', 'great. Take care'],
#  ['how are you', 'ok thanks', 'great. Take care'],
#  ['ok thanks', 'great. Take care'],
#  ['hi', 'how are you', 'okay thanks', 'great. Take care'],
#  ['how are you', 'okay thanks', 'great. Take care'],
#  ['okay thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'all right thanks', 'great. Take care'],
#  ['how are you', 'all right thanks', 'great. Take care'],
#  ['all right thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great. Take care'],
#  ['how are you', 'fine thanks', 'great. Take care'],
#  ['fine thanks', 'great. Take care'],
#  ['hi', 'how are you', 'fine thanks', 'dandy . Take care'],
#  ['how are you', 'fine thanks', 'dandy . Take care'],
#  ['fine thanks', 'dandy . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'capital . Take care'],
#  ['how are you', 'fine thanks', 'capital . Take care'],
#  ['fine thanks', 'capital . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'cracking . Take care'],
#  ['how are you', 'fine thanks', 'cracking . Take care'],
#  ['fine thanks', 'cracking . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'nifty . Take care'],
#  ['how are you', 'fine thanks', 'nifty . Take care'],
#  ['fine thanks', 'nifty . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'keen . Take care'],
#  ['how are you', 'fine thanks', 'keen . Take care'],
#  ['fine thanks', 'keen . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'neat . Take care'],
#  ['how are you', 'fine thanks', 'neat . Take care'],
#  ['fine thanks', 'neat . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'bang up . Take care'],
#  ['how are you', 'fine thanks', 'bang up . Take care'],
#  ['fine thanks', 'bang up . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'heavy . Take care'],
#  ['how are you', 'fine thanks', 'heavy . Take care'],
#  ['fine thanks', 'heavy . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'not bad . Take care'],
#  ['how are you', 'fine thanks', 'not bad . Take care'],
#  ['fine thanks', 'not bad . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take care'],
#  ['how are you', 'fine thanks', 'great . Take care'],
#  ['fine thanks', 'great . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'bully . Take care'],
#  ['how are you', 'fine thanks', 'bully . Take care'],
#  ['fine thanks', 'bully . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'big . Take care'],
#  ['how are you', 'fine thanks', 'big . Take care'],
#  ['fine thanks', 'big . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'large . Take care'],
#  ['how are you', 'fine thanks', 'large . Take care'],
#  ['fine thanks', 'large . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'majuscule . Take care'],
#  ['how are you', 'fine thanks', 'majuscule . Take care'],
#  ['fine thanks', 'majuscule . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'swell . Take care'],
#  ['how are you', 'fine thanks', 'swell . Take care'],
#  ['fine thanks', 'swell . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'expectant . Take care'],
#  ['how are you', 'fine thanks', 'expectant . Take care'],
#  ['fine thanks', 'expectant . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'gravid . Take care'],
#  ['how are you', 'fine thanks', 'gravid . Take care'],
#  ['fine thanks', 'gravid . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'smashing . Take care'],
#  ['how are you', 'fine thanks', 'smashing . Take care'],
#  ['fine thanks', 'smashing . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'peachy . Take care'],
#  ['how are you', 'fine thanks', 'peachy . Take care'],
#  ['fine thanks', 'peachy . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'outstanding . Take care'],
#  ['how are you', 'fine thanks', 'outstanding . Take care'],
#  ['fine thanks', 'outstanding . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'enceinte . Take care'],
#  ['how are you', 'fine thanks', 'enceinte . Take care'],
#  ['fine thanks', 'enceinte . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'with child . Take care'],
#  ['how are you', 'fine thanks', 'with child . Take care'],
#  ['fine thanks', 'with child . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'corking . Take care'],
#  ['how are you', 'fine thanks', 'corking . Take care'],
#  ['fine thanks', 'corking . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'slap up . Take care'],
#  ['how are you', 'fine thanks', 'slap up . Take care'],
#  ['fine thanks', 'slap up . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'groovy . Take care'],
#  ['how are you', 'fine thanks', 'groovy . Take care'],
#  ['fine thanks', 'groovy . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . return care'],
#  ['how are you', 'fine thanks', 'great . return care'],
#  ['fine thanks', 'great . return care'],
#  ['hi', 'how are you', 'fine thanks', 'great . issue care'],
#  ['how are you', 'fine thanks', 'great . issue care'],
#  ['fine thanks', 'great . issue care'],
#  ['hi', 'how are you', 'fine thanks', 'great . proceeds care'],
#  ['how are you', 'fine thanks', 'great . proceeds care'],
#  ['fine thanks', 'great . proceeds care'],
#  ['hi', 'how are you', 'fine thanks', 'great . yield care'],
#  ['how are you', 'fine thanks', 'great . yield care'],
#  ['fine thanks', 'great . yield care'],
#  ['hi', 'how are you', 'fine thanks', 'great . payoff care'],
#  ['how are you', 'fine thanks', 'great . payoff care'],
#  ['fine thanks', 'great . payoff care'],
#  ['hi', 'how are you', 'fine thanks', 'great . take care'],
#  ['how are you', 'fine thanks', 'great . take care'],
#  ['fine thanks', 'great . take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . takings care'],
#  ['how are you', 'fine thanks', 'great . takings care'],
#  ['fine thanks', 'great . takings care'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take tutelage'],
#  ['how are you', 'fine thanks', 'great . Take tutelage'],
#  ['fine thanks', 'great . Take tutelage'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take care'],
#  ['how are you', 'fine thanks', 'great . Take care'],
#  ['fine thanks', 'great . Take care'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take upkeep'],
#  ['how are you', 'fine thanks', 'great . Take upkeep'],
#  ['fine thanks', 'great . Take upkeep'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take fear'],
#  ['how are you', 'fine thanks', 'great . Take fear'],
#  ['fine thanks', 'great . Take fear'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take precaution'],
#  ['how are you', 'fine thanks', 'great . Take precaution'],
#  ['fine thanks', 'great . Take precaution'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take maintenance'],
#  ['how are you', 'fine thanks', 'great . Take maintenance'],
#  ['fine thanks', 'great . Take maintenance'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take guardianship'],
#  ['how are you', 'fine thanks', 'great . Take guardianship'],
#  ['fine thanks', 'great . Take guardianship'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take aid'],
#  ['how are you', 'fine thanks', 'great . Take aid'],
#  ['fine thanks', 'great . Take aid'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take forethought'],
#  ['how are you', 'fine thanks', 'great . Take forethought'],
#  ['fine thanks', 'great . Take forethought'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take concern'],
#  ['how are you', 'fine thanks', 'great . Take concern'],
#  ['fine thanks', 'great . Take concern'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take charge'],
#  ['how are you', 'fine thanks', 'great . Take charge'],
#  ['fine thanks', 'great . Take charge'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take caution'],
#  ['how are you', 'fine thanks', 'great . Take caution'],
#  ['fine thanks', 'great . Take caution'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take attention'],
#  ['how are you', 'fine thanks', 'great . Take attention'],
#  ['fine thanks', 'great . Take attention'],
#  ['hi', 'how are you', 'fine thanks', 'great . Take tending'],
#  ['how are you', 'fine thanks', 'great . Take tending'],
#  ['fine thanks', 'great . Take tending'],
#  ['heya',
#   'ugh go away',
#   'why are you and so mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you and so mean to me', 'im just in a bad mood'],
#  ['why are you and so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you therefore mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you therefore mean to me', 'im just in a bad mood'],
#  ['why are you therefore mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you then mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you then mean to me', 'im just in a bad mood'],
#  ['why are you then mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you thus mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you thus mean to me', 'im just in a bad mood'],
#  ['why are you thus mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you thence mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you thence mean to me', 'im just in a bad mood'],
#  ['why are you thence mean to me', 'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you hence mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you hence mean to me', 'im just in a bad mood'],
#  ['why are you hence mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you thusly mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you thusly mean to me', 'im just in a bad mood'],
#  ['why are you thusly mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you indeed mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you indeed mean to me', 'im just in a bad mood'],
#  ['why are you indeed mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you and then mean to me',
#   'im just in a bad mood'],
#  ['ugh go away', 'why are you and then mean to me', 'im just in a bad mood'],
#  ['why are you and then mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im simply in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im simply in a bad mood'],
#  ['why are you so mean to me', 'im simply in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im precisely in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im precisely in a bad mood'],
#  ['why are you so mean to me', 'im precisely in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im but in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im but in a bad mood'],
#  ['why are you so mean to me', 'im but in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im exactly in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im exactly in a bad mood'],
#  ['why are you so mean to me', 'im exactly in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im barely in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im barely in a bad mood'],
#  ['why are you so mean to me', 'im barely in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im hardly in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im hardly in a bad mood'],
#  ['why are you so mean to me', 'im hardly in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im scarce in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im scarce in a bad mood'],
#  ['why are you so mean to me', 'im scarce in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im only in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im only in a bad mood'],
#  ['why are you so mean to me', 'im only in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just now in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just now in a bad mood'],
#  ['why are you so mean to me', 'im just now in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im scarcely in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im scarcely in a bad mood'],
#  ['why are you so mean to me', 'im scarcely in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im merely in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im merely in a bad mood'],
#  ['why are you so mean to me', 'im merely in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a unfit mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a unfit mood'],
#  ['why are you so mean to me', 'im just in a unfit mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a tough mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a tough mood'],
#  ['why are you so mean to me', 'im just in a tough mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a sorry mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a sorry mood'],
#  ['why are you so mean to me', 'im just in a sorry mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a risky mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a risky mood'],
#  ['why are you so mean to me', 'im just in a risky mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a high risk mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a high risk mood'],
#  ['why are you so mean to me', 'im just in a high risk mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a forged mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a forged mood'],
#  ['why are you so mean to me', 'im just in a forged mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a spoiled mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a spoiled mood'],
#  ['why are you so mean to me', 'im just in a spoiled mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['why are you so mean to me', 'im just in a bad mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a regretful mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a regretful mood'],
#  ['why are you so mean to me', 'im just in a regretful mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a speculative mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a speculative mood'],
#  ['why are you so mean to me', 'im just in a speculative mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a uncollectible mood'],
#  ['ugh go away',
#   'why are you so mean to me',
#   'im just in a uncollectible mood'],
#  ['why are you so mean to me', 'im just in a uncollectible mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a defective mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a defective mood'],
#  ['why are you so mean to me', 'im just in a defective mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a big mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a big mood'],
#  ['why are you so mean to me', 'im just in a big mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a unsound mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a unsound mood'],
#  ['why are you so mean to me', 'im just in a unsound mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a spoilt mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a spoilt mood'],
#  ['why are you so mean to me', 'im just in a spoilt mood'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad temper'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad temper'],
#  ['why are you so mean to me', 'im just in a bad temper'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mood'],
#  ['why are you so mean to me', 'im just in a bad mood'],
#  ['heya', 'ugh go away', 'why are you so mean to me', 'im just in a bad mode'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad mode'],
#  ['why are you so mean to me', 'im just in a bad mode'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad climate'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad climate'],
#  ['why are you so mean to me', 'im just in a bad climate'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad modality'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad modality'],
#  ['why are you so mean to me', 'im just in a bad modality'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad humor'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad humor'],
#  ['why are you so mean to me', 'im just in a bad humor'],
#  ['heya',
#   'ugh go away',
#   'why are you so mean to me',
#   'im just in a bad humour'],
#  ['ugh go away', 'why are you so mean to me', 'im just in a bad humour'],
#  ['why are you so mean to me', 'im just in a bad humour'],
#  ['what is your figure', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your gens', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your public figure',
#   'im Carla',
#   'nice to meet you Carla',
#   'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your epithet', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'overnice to meet you Carla', 'likewise'],
#  ['im Carla', 'overnice to meet you Carla', 'likewise'],
#  ['overnice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'gracious to meet you Carla', 'likewise'],
#  ['im Carla', 'gracious to meet you Carla', 'likewise'],
#  ['gracious to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'squeamish to meet you Carla', 'likewise'],
#  ['im Carla', 'squeamish to meet you Carla', 'likewise'],
#  ['squeamish to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'prissy to meet you Carla', 'likewise'],
#  ['im Carla', 'prissy to meet you Carla', 'likewise'],
#  ['prissy to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'dainty to meet you Carla', 'likewise'],
#  ['im Carla', 'dainty to meet you Carla', 'likewise'],
#  ['dainty to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'decent to meet you Carla', 'likewise'],
#  ['im Carla', 'decent to meet you Carla', 'likewise'],
#  ['decent to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'skillful to meet you Carla', 'likewise'],
#  ['im Carla', 'skillful to meet you Carla', 'likewise'],
#  ['skillful to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'courteous to meet you Carla', 'likewise'],
#  ['im Carla', 'courteous to meet you Carla', 'likewise'],
#  ['courteous to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'similarly'],
#  ['im Carla', 'nice to meet you Carla', 'similarly'],
#  ['nice to meet you Carla', 'similarly'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'besides'],
#  ['im Carla', 'nice to meet you Carla', 'besides'],
#  ['nice to meet you Carla', 'besides'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'as well'],
#  ['im Carla', 'nice to meet you Carla', 'as well'],
#  ['nice to meet you Carla', 'as well'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'alike'],
#  ['im Carla', 'nice to meet you Carla', 'alike'],
#  ['nice to meet you Carla', 'alike'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'too'],
#  ['im Carla', 'nice to meet you Carla', 'too'],
#  ['nice to meet you Carla', 'too'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'likewise'],
#  ['im Carla', 'nice to meet you Carla', 'likewise'],
#  ['nice to meet you Carla', 'likewise'],
#  ['what is your name', 'im Carla', 'nice to meet you Carla', 'also'],
#  ['im Carla', 'nice to meet you Carla', 'also'],
#  ['nice to meet you Carla', 'also'],
#  ['how do you do .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hello .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['Hawaii .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hullo .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['howdy .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['Aloha State .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ["Hawai'i .",
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['HI .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi .',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'o.k. thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'o.k. thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['o.k. thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'hunky dory thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'hunky dory thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['hunky dory thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'ok thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'ok thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['ok thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'okay thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'okay thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['okay thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'all right thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'all right thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['all right thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks .',
#   'great.',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks .', 'great.', 'Take care.', 'And thank you so much.'],
#  ['great.', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'dandy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'dandy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'dandy .', 'Take care.', 'And thank you so much.'],
#  ['dandy .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'capital .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'capital .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'capital .', 'Take care.', 'And thank you so much.'],
#  ['capital .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'cracking .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'cracking .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'cracking .', 'Take care.', 'And thank you so much.'],
#  ['cracking .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'nifty .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'nifty .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'nifty .', 'Take care.', 'And thank you so much.'],
#  ['nifty .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'keen .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'keen .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'keen .', 'Take care.', 'And thank you so much.'],
#  ['keen .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'neat .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'neat .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'neat .', 'Take care.', 'And thank you so much.'],
#  ['neat .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'bang up .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'bang up .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'bang up .', 'Take care.', 'And thank you so much.'],
#  ['bang up .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'heavy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'heavy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'heavy .', 'Take care.', 'And thank you so much.'],
#  ['heavy .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'not bad .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'not bad .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'not bad .', 'Take care.', 'And thank you so much.'],
#  ['not bad .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'great .', 'Take care.', 'And thank you so much.'],
#  ['great .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'bully .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'bully .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'bully .', 'Take care.', 'And thank you so much.'],
#  ['bully .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'big .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'big .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'big .', 'Take care.', 'And thank you so much.'],
#  ['big .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'large .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'large .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'large .', 'Take care.', 'And thank you so much.'],
#  ['large .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'majuscule .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'majuscule .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'majuscule .', 'Take care.', 'And thank you so much.'],
#  ['majuscule .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'swell .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'swell .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'swell .', 'Take care.', 'And thank you so much.'],
#  ['swell .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'expectant .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'expectant .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'expectant .', 'Take care.', 'And thank you so much.'],
#  ['expectant .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'gravid .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'gravid .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'gravid .', 'Take care.', 'And thank you so much.'],
#  ['gravid .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'smashing .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'smashing .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'smashing .', 'Take care.', 'And thank you so much.'],
#  ['smashing .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'peachy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'peachy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'peachy .', 'Take care.', 'And thank you so much.'],
#  ['peachy .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'outstanding .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'outstanding .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'outstanding .', 'Take care.', 'And thank you so much.'],
#  ['outstanding .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'enceinte .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'enceinte .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'enceinte .', 'Take care.', 'And thank you so much.'],
#  ['enceinte .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'with child .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'with child .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'with child .', 'Take care.', 'And thank you so much.'],
#  ['with child .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'corking .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'corking .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'corking .', 'Take care.', 'And thank you so much.'],
#  ['corking .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'slap up .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'slap up .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'slap up .', 'Take care.', 'And thank you so much.'],
#  ['slap up .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'groovy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'groovy .',
#   'Take care.',
#   'And thank you so much.'],
#  ['fine thanks.', 'groovy .', 'Take care.', 'And thank you so much.'],
#  ['groovy .', 'Take care.', 'And thank you so much.'],
#  ['Take care.', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'return care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'return care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'return care .', 'And thank you so much.'],
#  ['great.', 'return care .', 'And thank you so much.'],
#  ['return care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'issue care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'issue care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'issue care .', 'And thank you so much.'],
#  ['great.', 'issue care .', 'And thank you so much.'],
#  ['issue care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'proceeds care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'proceeds care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'proceeds care .', 'And thank you so much.'],
#  ['great.', 'proceeds care .', 'And thank you so much.'],
#  ['proceeds care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'yield care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'yield care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'yield care .', 'And thank you so much.'],
#  ['great.', 'yield care .', 'And thank you so much.'],
#  ['yield care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'payoff care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'payoff care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'payoff care .', 'And thank you so much.'],
#  ['great.', 'payoff care .', 'And thank you so much.'],
#  ['payoff care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'take care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'take care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'take care .', 'And thank you so much.'],
#  ['great.', 'take care .', 'And thank you so much.'],
#  ['take care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'takings care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'takings care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'takings care .', 'And thank you so much.'],
#  ['great.', 'takings care .', 'And thank you so much.'],
#  ['takings care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take tutelage .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take tutelage .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take tutelage .', 'And thank you so much.'],
#  ['great.', 'Take tutelage .', 'And thank you so much.'],
#  ['Take tutelage .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take care .', 'And thank you so much.'],
#  ['great.', 'Take care .', 'And thank you so much.'],
#  ['Take care .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take upkeep .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take upkeep .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take upkeep .', 'And thank you so much.'],
#  ['great.', 'Take upkeep .', 'And thank you so much.'],
#  ['Take upkeep .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take fear .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take fear .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take fear .', 'And thank you so much.'],
#  ['great.', 'Take fear .', 'And thank you so much.'],
#  ['Take fear .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take precaution .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take precaution .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take precaution .', 'And thank you so much.'],
#  ['great.', 'Take precaution .', 'And thank you so much.'],
#  ['Take precaution .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take maintenance .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take maintenance .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take maintenance .', 'And thank you so much.'],
#  ['great.', 'Take maintenance .', 'And thank you so much.'],
#  ['Take maintenance .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take guardianship .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take guardianship .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take guardianship .', 'And thank you so much.'],
#  ['great.', 'Take guardianship .', 'And thank you so much.'],
#  ['Take guardianship .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take aid .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take aid .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take aid .', 'And thank you so much.'],
#  ['great.', 'Take aid .', 'And thank you so much.'],
#  ['Take aid .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take forethought .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take forethought .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take forethought .', 'And thank you so much.'],
#  ['great.', 'Take forethought .', 'And thank you so much.'],
#  ['Take forethought .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take concern .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take concern .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take concern .', 'And thank you so much.'],
#  ['great.', 'Take concern .', 'And thank you so much.'],
#  ['Take concern .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take charge .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take charge .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take charge .', 'And thank you so much.'],
#  ['great.', 'Take charge .', 'And thank you so much.'],
#  ['Take charge .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take caution .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take caution .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take caution .', 'And thank you so much.'],
#  ['great.', 'Take caution .', 'And thank you so much.'],
#  ['Take caution .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take attention .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take attention .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take attention .', 'And thank you so much.'],
#  ['great.', 'Take attention .', 'And thank you so much.'],
#  ['Take attention .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take tending .',
#   'And thank you so much.'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take tending .',
#   'And thank you so much.'],
#  ['fine thanks.', 'great.', 'Take tending .', 'And thank you so much.'],
#  ['great.', 'Take tending .', 'And thank you so much.'],
#  ['Take tending .', 'And thank you so much.'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you and so much .'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you and so much .'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you and so much .'],
#  ['great.', 'Take care.', 'And thank you and so much .'],
#  ['Take care.', 'And thank you and so much .'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you therefore much .'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you therefore much .'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you therefore much .'],
#  ['great.', 'Take care.', 'And thank you therefore much .'],
#  ['Take care.', 'And thank you therefore much .'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you then much .'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you then much .'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you then much .'],
#  ['great.', 'Take care.', 'And thank you then much .'],
#  ['Take care.', 'And thank you then much .'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you thus much .'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you thus much .'],
#  ['fine thanks.', 'great.', 'Take care.', 'And thank you thus much .'],
#  ['great.', 'Take care.', 'And thank you thus much .'],
#  ['Take care.', 'And thank you thus much .'],
#  ['hi.',
#   'how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
#   'And thank you thence much .'],
#  ['how are you.',
#   'fine thanks.',
#   'great.',
#   'Take care.',
# ...
#  ['im simply in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im precisely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im precisely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im precisely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im precisely in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im but in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im but in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im but in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im but in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im just in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im exactly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im exactly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im exactly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im exactly in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im barely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im barely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im barely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im barely in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im hardly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im hardly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im hardly in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im hardly in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im scarce in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im scarce in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im scarce in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im scarce in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im only in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im only in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im only in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im only in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just now in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just now in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just now in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im just now in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im scarcely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im scarcely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im scarcely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im scarcely in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im merely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im merely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im merely in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im merely in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a unfit mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a unfit mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a unfit mood .',
#   'i wish i was in the other room.'],
#  ['im just in a unfit mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a tough mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a tough mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a tough mood .',
#   'i wish i was in the other room.'],
#  ['im just in a tough mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a sorry mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a sorry mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a sorry mood .',
#   'i wish i was in the other room.'],
#  ['im just in a sorry mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a risky mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a risky mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a risky mood .',
#   'i wish i was in the other room.'],
#  ['im just in a risky mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a high risk mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a high risk mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a high risk mood .',
#   'i wish i was in the other room.'],
#  ['im just in a high risk mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a forged mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a forged mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a forged mood .',
#   'i wish i was in the other room.'],
#  ['im just in a forged mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a spoiled mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a spoiled mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a spoiled mood .',
#   'i wish i was in the other room.'],
#  ['im just in a spoiled mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im just in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a regretful mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a regretful mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a regretful mood .',
#   'i wish i was in the other room.'],
#  ['im just in a regretful mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a speculative mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a speculative mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a speculative mood .',
#   'i wish i was in the other room.'],
#  ['im just in a speculative mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a uncollectible mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a uncollectible mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a uncollectible mood .',
#   'i wish i was in the other room.'],
#  ['im just in a uncollectible mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a defective mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a defective mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a defective mood .',
#   'i wish i was in the other room.'],
#  ['im just in a defective mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a big mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a big mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a big mood .',
#   'i wish i was in the other room.'],
#  ['im just in a big mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a unsound mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a unsound mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a unsound mood .',
#   'i wish i was in the other room.'],
#  ['im just in a unsound mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a spoilt mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a spoilt mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a spoilt mood .',
#   'i wish i was in the other room.'],
#  ['im just in a spoilt mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad temper .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad temper .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad temper .',
#   'i wish i was in the other room.'],
#  ['im just in a bad temper .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad mood .',
#   'i wish i was in the other room.'],
#  ['im just in a bad mood .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mode .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mode .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad mode .',
#   'i wish i was in the other room.'],
#  ['im just in a bad mode .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad climate .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad climate .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad climate .',
#   'i wish i was in the other room.'],
#  ['im just in a bad climate .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad modality .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad modality .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad modality .',
#   'i wish i was in the other room.'],
#  ['im just in a bad modality .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad humor .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad humor .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad humor .',
#   'i wish i was in the other room.'],
#  ['im just in a bad humor .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad humour .',
#   'i wish i was in the other room.'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad humour .',
#   'i wish i was in the other room.'],
#  ['why are you so mean to me.',
#   'im just in a bad humour .',
#   'i wish i was in the other room.'],
#  ['im just in a bad humour .', 'i wish i was in the other room.'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish i was in the other room .'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish i was in the other room .'],
#  ['why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish i was in the other room .'],
#  ['im just in a bad mood.', 'i wish i was in the other room .'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'one wish i was in the other room .'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'one wish i was in the other room .'],
#  ['why are you so mean to me.',
#   'im just in a bad mood.',
#   'one wish i was in the other room .'],
#  ['im just in a bad mood.', 'one wish i was in the other room .'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'ane wish i was in the other room .'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'ane wish i was in the other room .'],
#  ['why are you so mean to me.',
#   'im just in a bad mood.',
#   'ane wish i was in the other room .'],
#  ['im just in a bad mood.', 'ane wish i was in the other room .'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   '1 wish i was in the other room .'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   '1 wish i was in the other room .'],
#  ['why are you so mean to me.',
#   'im just in a bad mood.',
#   '1 wish i was in the other room .'],
#  ['im just in a bad mood.', '1 wish i was in the other room .'],
#  ['heya.',
#   'ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish atomic number 53 was in the other room .'],
#  ['ugh go away.',
#   'why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish atomic number 53 was in the other room .'],
#  ['why are you so mean to me.',
#   'im just in a bad mood.',
#   'i wish atomic number 53 was in the other room .'],
#  ...]

# %%
len(augmented_dataset)
# Out:
# 38293
